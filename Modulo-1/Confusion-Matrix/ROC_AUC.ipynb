# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
pd.set_option('display.max_columns', 30)
dados = load_breast_cancer()
x = pd.DataFrame(dados.data, columns=[dados.feature_names])
y = pd.Series(dados.target)

# %%
x.head()
# Out:
#   mean radius mean texture mean perimeter mean area mean smoothness  \
# 0       17.99        10.38         122.80    1001.0         0.11840
# 1       20.57        17.77         132.90    1326.0         0.08474
# 2       19.69        21.25         130.00    1203.0         0.10960
# 3       11.42        20.38          77.58     386.1         0.14250
# 4       20.29        14.34         135.10    1297.0         0.10030
#
#   mean compactness mean concavity mean concave points mean symmetry  \
# 0          0.27760         0.3001             0.14710        0.2419
# 1          0.07864         0.0869             0.07017        0.1812
# 2          0.15990         0.1974             0.12790        0.2069
# 3          0.28390         0.2414             0.10520        0.2597
# 4          0.13280         0.1980             0.10430        0.1809
#
#   mean fractal dimension radius error texture error perimeter error  \
# 0                0.07871       1.0950        0.9053           8.589
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X_treino, X_teste, Y_treino, Y_teste = train_test_split(x, y, test_size = 0.3, random_state = 9)

modelo = LogisticRegression(C=95, penalty='l1', solver='liblinear', max_iter=1000)
modelo.fit(X_treino, Y_treino)
resultado = modelo.score(X_teste, Y_teste)
print('Acuracy', resultado)
# Out:
# Acuracy 0.9766081871345029

# %%
predicoes = modelo.predict_proba(X_teste)

# %%
predicoes
# Out:
# array([[7.92771845e-01, 2.07228155e-01],
#        [1.11961053e-01, 8.88038947e-01],
#        [1.00000000e+00, 2.73894276e-14],
#        [1.07686834e-01, 8.92313166e-01],
#        [1.95513307e-05, 9.99980449e-01],
#        [1.00000000e+00, 2.20211506e-20],
#        [1.00000000e+00, 4.93923677e-15],
#        [1.00000000e+00, 2.16723029e-11],
#        [4.40802850e-06, 9.99995592e-01],
#        [9.99999993e-01, 6.72936775e-09],
#        [1.00000000e+00, 2.64982210e-14],
#        [1.97022431e-05, 9.99980298e-01],
#        [3.68033133e-06, 9.99996320e-01],
#        [5.22129198e-05, 9.99947787e-01],
#        [9.99999883e-01, 1.17018807e-07],
#        [1.68833321e-02, 9.83116668e-01],
#        [2.90815694e-06, 9.99997092e-01],
#        [2.98982699e-02, 9.70101730e-01],
#        [1.68023789e-06, 9.99998320e-01],
#        [3.23750430e-07, 9.99999676e-01],
#        [1.00000000e+00, 1.67771630e-35],
#        [3.08151099e-07, 9.99999692e-01],
#        [9.80651806e-04, 9.99019348e-01],
# ...

# %%
probs = predicoes[:, 1]

# %%
from sklearn.metrics import roc_curve
fpr, tpr , thresholds = roc_curve(Y_teste, probs)

# %%
print('TPR', tpr)
print('FPR', fpr)
print('Theresholds', thresholds)
# Out:
# TPR [0.         0.00917431 0.91743119 0.91743119 0.95412844 0.95412844
#  0.98165138 0.98165138 0.99082569 0.99082569 1.         1.        ]
# FPR [0.         0.         0.         0.01612903 0.01612903 0.03225806
#  0.03225806 0.0483871  0.0483871  0.09677419 0.09677419 1.        ]
# Theresholds [2.00000000e+00 9.99999998e-01 9.34453552e-01 9.22415335e-01
#  8.92313166e-01 8.88038947e-01 7.36929528e-01 6.71004178e-01
#  5.84262696e-01 2.40333870e-01 2.12509353e-01 2.03811961e-46]

# %%
import matplotlib.pyplot as plt
plt.scatter(fpr, tpr)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
print(roc_auc_score(Y_teste, probs))
# Out:
# 0.9971885173128144
